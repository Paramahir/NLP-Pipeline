# %% [markdown]
# <h1>Install Following</h1>
#
# pip install nltk <br>
# pip install spacy<br>
# python -m spacy download en_core_web_sm

# %% [markdown]
# # Sentence Segmentation

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
text = "Mumbai or Bombay is the capital city of the Indian State of Maharashtra. According to the United Nations, as of 2018, Mumbai was the second most populated city in India after Delhi. In the world with a population of roughly 20 million. As per the Indian government population census of 2011, Mumbai was the most populated city in India. An estimated city-proper population of 12.5 million living under Municipal Corporation of Greater Mumbai."

# %%
sentences = nltk.sent_tokenize(text)

# %%
for sentence in sentences:
    print(sentence)
# Out:
# Mumbai or Bombay is the capital city of the Indian State of Maharashtra.
# According to the United Nations, as of 2018, Mumbai was the second most populated city in India after Delhi.
# In the world with a population of roughly 20 million.
# As per the Indian government population census of 2011, Mumbai was the most populated city in India.
# An estimated city-proper population of 12.5 million living under Municipal Corporation of Greater Mumbai.

# %% [markdown]
# # White Space Tokenization

# %%
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    for word in words:
        print(word)
# Out:
# Mumbai
# or
# Bombay
# is
# the
# capital
# city
# of
# the
# Indian
# State
# of
# Maharashtra
# .
# According
# to
# the
# United
# Nations
# ,
# as
# of
# 2018
# ,
# Mumbai
# was
# the
# second
# most
# populated
# city
# in
# India
# after
# Delhi
# .
# In
# the
# world
# with
# a
# population
# of
# roughly
# 20
# million
# .
# As
# per
# the
# Indian
# government
# population
# census
# of
# 2011
# ,
# Mumbai
# was
# the
# most
# populated
# city
# in
# India
# .
# An
# estimated
# city-proper
# population
# of
# 12.5
# million
# living
# under
# Municipal
# Corporation
# of
# Greater
# Mumbai
# .

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    for word in words:
        rootWord=ps.stem(word)
        print("Root of ",word," is ",rootWord)
# Out:
# Root of  Mumbai  is  mumbai
# Root of  or  is  or
# Root of  Bombay  is  bombay
# Root of  is  is  is
# Root of  the  is  the
# Root of  capital  is  capit
# Root of  city  is  citi
# Root of  of  is  of
# Root of  the  is  the
# Root of  Indian  is  indian
# Root of  State  is  state
# Root of  of  is  of
# Root of  Maharashtra  is  maharashtra
# Root of  .  is  .
# Root of  According  is  accord
# Root of  to  is  to
# Root of  the  is  the
# Root of  United  is  unit
# Root of  Nations  is  nation
# Root of  ,  is  ,
# Root of  as  is  as
# Root of  of  is  of
# Root of  2018  is  2018
# Root of  ,  is  ,
# Root of  Mumbai  is  mumbai
# Root of  was  is  wa
# Root of  the  is  the
# Root of  second  is  second
# Root of  most  is  most
# Root of  populated  is  popul
# Root of  city  is  citi
# Root of  in  is  in
# Root of  India  is  india
# Root of  after  is  after
# Root of  Delhi  is  delhi
# Root of  .  is  .
# Root of  In  is  In
# Root of  the  is  the
# Root of  world  is  world
# Root of  with  is  with
# Root of  a  is  a
# Root of  population  is  popul
# Root of  of  is  of
# Root of  roughly  is  roughli
# Root of  20  is  20
# Root of  million  is  million
# Root of  .  is  .
# Root of  As  is  As
# Root of  per  is  per
# Root of  the  is  the
# Root of  Indian  is  indian
# Root of  government  is  govern
# Root of  population  is  popul
# Root of  census  is  censu
# Root of  of  is  of
# Root of  2011  is  2011
# Root of  ,  is  ,
# Root of  Mumbai  is  mumbai
# Root of  was  is  wa
# Root of  the  is  the
# Root of  most  is  most
# Root of  populated  is  popul
# Root of  city  is  citi
# Root of  in  is  in
# Root of  India  is  india
# Root of  .  is  .
# Root of  An  is  An
# Root of  estimated  is  estim
# Root of  city-proper  is  city-prop
# Root of  population  is  popul
# Root of  of  is  of
# Root of  12.5  is  12.5
# Root of  million  is  million
# Root of  living  is  live
# Root of  under  is  under
# Root of  Municipal  is  municip
# Root of  Corporation  is  corpor
# Root of  of  is  of
# Root of  Greater  is  greater
# Root of  Mumbai  is  mumbai
# Root of  .  is  .

# %% [markdown]
# # Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    for word in words:
        rootWord=wordnet_lemmatizer.lemmatize(word)
        print("Lemma of ",word," is ",rootWord)
# Out:
# Lemma of  Mumbai  is  Mumbai
# Lemma of  or  is  or
# Lemma of  Bombay  is  Bombay
# Lemma of  is  is  is
# Lemma of  the  is  the
# Lemma of  capital  is  capital
# Lemma of  city  is  city
# Lemma of  of  is  of
# Lemma of  the  is  the
# Lemma of  Indian  is  Indian
# Lemma of  State  is  State
# Lemma of  of  is  of
# Lemma of  Maharashtra  is  Maharashtra
# Lemma of  .  is  .
# Lemma of  According  is  According
# Lemma of  to  is  to
# Lemma of  the  is  the
# Lemma of  United  is  United
# Lemma of  Nations  is  Nations
# Lemma of  ,  is  ,
# Lemma of  as  is  a
# Lemma of  of  is  of
# Lemma of  2018  is  2018
# Lemma of  ,  is  ,
# Lemma of  Mumbai  is  Mumbai
# Lemma of  was  is  wa
# Lemma of  the  is  the
# Lemma of  second  is  second
# Lemma of  most  is  most
# Lemma of  populated  is  populated
# Lemma of  city  is  city
# Lemma of  in  is  in
# Lemma of  India  is  India
# Lemma of  after  is  after
# Lemma of  Delhi  is  Delhi
# Lemma of  .  is  .
# Lemma of  In  is  In
# Lemma of  the  is  the
# Lemma of  world  is  world
# Lemma of  with  is  with
# Lemma of  a  is  a
# Lemma of  population  is  population
# Lemma of  of  is  of
# Lemma of  roughly  is  roughly
# Lemma of  20  is  20
# Lemma of  million  is  million
# Lemma of  .  is  .
# Lemma of  As  is  As
# Lemma of  per  is  per
# Lemma of  the  is  the
# Lemma of  Indian  is  Indian
# Lemma of  government  is  government
# Lemma of  population  is  population
# Lemma of  census  is  census
# Lemma of  of  is  of
# Lemma of  2011  is  2011
# Lemma of  ,  is  ,
# Lemma of  Mumbai  is  Mumbai
# Lemma of  was  is  wa
# Lemma of  the  is  the
# Lemma of  most  is  most
# Lemma of  populated  is  populated
# Lemma of  city  is  city
# Lemma of  in  is  in
# Lemma of  India  is  India
# Lemma of  .  is  .
# Lemma of  An  is  An
# Lemma of  estimated  is  estimated
# Lemma of  city-proper  is  city-proper
# Lemma of  population  is  population
# Lemma of  of  is  of
# Lemma of  12.5  is  12.5
# Lemma of  million  is  million
# Lemma of  living  is  living
# Lemma of  under  is  under
# Lemma of  Municipal  is  Municipal
# Lemma of  Corporation  is  Corporation
# Lemma of  of  is  of
# Lemma of  Greater  is  Greater
# Lemma of  Mumbai  is  Mumbai
# Lemma of  .  is  .

# %% [markdown]
# # Stop Word Removal

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
stop_words = stopwords.words('english')

 
text_tokens = nltk.word_tokenize(text)
tokens_without_sw = [word for word in text_tokens if not word in stop_words]

print(tokens_without_sw)
# Out:
# ['Mumbai', 'Bombay', 'capital', 'city', 'Indian', 'State', 'Maharashtra', '.', 'According', 'United', 'Nations', ',', '2018', ',', 'Mumbai', 'second', 'populated', 'city', 'India', 'Delhi', '.', 'In', 'world', 'population', 'roughly', '20', 'million', '.', 'As', 'per', 'Indian', 'government', 'population', 'census', '2011', ',', 'Mumbai', 'populated', 'city', 'India', '.', 'An', 'estimated', 'city-proper', 'population', '12.5', 'million', 'living', 'Municipal', 'Corporation', 'Greater', 'Mumbai', '.']

# %% [markdown]
# # Part of Speech Tagging

# %%
import spacy
sp = spacy.load('en_core_web_sm')

# %%
for sentence in sentences:
    sen = sp(sentence)
    displacy.render(sen, style='dep', jupyter=True, options={'distance': 85})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b50ce7063ebd4ce9b861b1c0b1521283-0" class="displacy" width="1155" height="264.5" direction="ltr" style="max-width: none; height: 264.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mumbai</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="135">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="220">Bombay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="220">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="305">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="305">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="390">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="390">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="475">capital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="475">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="560">city</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="560">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="645">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="645">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="730">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="815">Indian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="815">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="900">State</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="985">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="985">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="1070">Maharashtra.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1070">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-0" stroke-width="2px" d="M70,129.5 C70,2.0 305.0,2.0 305.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,131.5 L62,119.5 78,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-1" stroke-width="2px" d="M70,129.5 C70,87.0 125.0,87.0 125.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M125.0,131.5 L133.0,119.5 117.0,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-2" stroke-width="2px" d="M70,129.5 C70,44.5 215.0,44.5 215.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,131.5 L223.0,119.5 207.0,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-3" stroke-width="2px" d="M410,129.5 C410,44.5 555.0,44.5 555.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M410,131.5 L402,119.5 418,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-4" stroke-width="2px" d="M495,129.5 C495,87.0 550.0,87.0 550.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M495,131.5 L487,119.5 503,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-5" stroke-width="2px" d="M325,129.5 C325,2.0 560.0,2.0 560.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,131.5 L568.0,119.5 552.0,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-6" stroke-width="2px" d="M580,129.5 C580,87.0 635.0,87.0 635.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b50ce7063ebd4ce9b861b1c0b1521283-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M635.0,131.5 L643.0,119.5 627.0,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b50ce7063ebd4ce9b861b1c0b1521283-0
tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1155">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="1240">Mumbai.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1240">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7601555c88794990ba965e10e4d1484b-0-0" stroke-width="2px" d="M70,172.0 C70,2.0 390.0,2.0 390.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7601555c88794990ba965e10e4d1484b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,174.0 L62,162.0 78,162.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7601555c88794990ba965e10e4d1484b-0-1" stroke-width="2px" d="M155,172.0 C155,44.5 385.0,44.5 385.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7601555c88794990ba965e10e4d1484b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M155,174.0 L147,162.0 163,162.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7601555c88794990ba965e10e4d1484b-0-2" stroke-width="2px" d="M240,172.0 C240,129.5 290.0,129.5 290.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7601555c88794990ba965e10e4d1484b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M240,174.0 L232,162.0 248,162.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7601555c88794990ba965e10e4d1484b-0-3" stroke-width="2px" d="M325,172.0 C325,129.5 375.0,129.5 375.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7601555c88794990ba965e10e4d1484b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M325,174.0 L317,162.0 333,162.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7601555c88794990ba965e10e4d1484b-0-4" stroke-width="2px" d="M410,172.0 C410,129.5 460.0,129.5 460.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7601555c88794990ba965e10e4d1484b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M460.0,174.0 L468.0,162.0 452.0,162.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7601555c88794990ba965e10e4d1484b-0-5" stroke-width="2px" d="M580,172.0 C580,129.5 630.0,129.5 630.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7601555c88794990ba965e10e4d1484b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M580,174.0 L572,162.0 588,162.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7601555c88794990ba965e10e4d1484b-0-6" stroke-width="2px" d="M495,172.0 C495,87.0 635.0,87.0 635.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7601555c88794990ba965e10e4d1484b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>

# %% [markdown]
# # Named Entity Recognition

# %%
sen = sp(text)
print(sen.ents)
# Out:
# (Mumbai, Bombay, the Indian State of Maharashtra, the United Nations, 2018, Mumbai, second, India, Delhi, roughly 20 million, Indian, 2011, Mumbai, India, 12.5 million)

# %%
sen = sp(text)
    
for entity in sen.ents:
    print(entity.text + ' - ' + entity.label_ + ' - ' + str(spacy.explain(entity.label_)))
# Out:
# Mumbai - GPE - Countries, cities, states
# Bombay - GPE - Countries, cities, states
# the Indian State of Maharashtra - GPE - Countries, cities, states
# the United Nations - ORG - Companies, agencies, institutions, etc.
# 2018 - DATE - Absolute or relative dates or periods
# Mumbai - GPE - Countries, cities, states
# second - ORDINAL - "first", "second", etc.
# India - GPE - Countries, cities, states
# Delhi - GPE - Countries, cities, states
# roughly 20 million - CARDINAL - Numerals that do not fall under another type
# Indian - NORP - Nationalities or religious or political groups
# 2011 - DATE - Absolute or relative dates or periods
# Mumbai - GPE - Countries, cities, states
# India - GPE - Countries, cities, states
# 12.5 million - CARDINAL - Numerals that do not fall under another type

# %%
len([ent for ent in sen.ents if ent.label_=='GPE'])
# Out:
# 8

# %%
displacy.render(sen, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bombay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is the capital city of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indian State of Maharashtra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . According to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Nations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  most populated city in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  after
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In the world with a population of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly 20 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . As per the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  government population census of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2011
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was the most populated city in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . An estimated city-proper population of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12.5 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  living under Municipal Corporation of Greater Mumbai.</div></span>
